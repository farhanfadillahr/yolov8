# %%
SOURCE_VIDEO = "/Users/farhanfadillahr/Documents/data/Kerja/yolov8/assets/input/sjn2_11.45-12.00.mp4"
DESTINATION_VIDEO = "/Users/farhanfadillahr/Documents/data/Kerja/yolov8/assets/output/experiment-5fps.avi"
CUSTOM_TRACK = "/Users/farhanfadillahr/Documents/data/Kerja/yolov8/assets/custom_track.yaml"

# %%
import torch
import cv2 
import numpy as np
import pathlib
import matplotlib.pyplot as plt
from ultralytics import YOLO
from collections import deque
from datetime import datetime
from collections import defaultdict
import time
# from ultralytics.solutions import object_counter

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.11.3 torch-2.0.1 CPU (Apple M1)
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 218.0/228.3 GB disk)

# %%
# Ultralytics YOLO 🚀, AGPL-3.0 license

from collections import defaultdict

import cv2

from ultralytics.utils.checks import check_imshow, check_requirements
from ultralytics.utils.plotting import Annotator, colors

check_requirements("shapely>=2.0.0")

from shapely.geometry import LineString, Point, Polygon


class ObjectCounter:
    """A class to manage the counting of objects in a real-time video stream based on their tracks."""

    def __init__(self):
        """Initializes the Counter with default values for various tracking and counting parameters."""

        # Mouse events
        self.is_drawing = False
        self.selected_point = None

        # Region & Line Information
        self.reg_pts = [(20, 400), (1260, 400)]
        self.line_dist_thresh = 15
        self.counting_region = None
        self.region_color = (255, 0, 255)
        self.region_thickness = 5

        # Image and annotation Information
        self.im0 = None
        self.tf = None
        self.view_img = False
        self.view_in_counts = True
        self.view_out_counts = True

        self.names = None  # Classes names
        self.annotator = None  # Annotator

        # Object counting Information
        self.in_counts = 0
        self.out_counts = 0
        self.counting_list = []
        self.count_txt_thickness = 0
        self.count_txt_color = (0, 0, 0)
        self.count_color = (255, 255, 255)

        # Tracks info
        self.track_history = defaultdict(list)
        self.track_thickness = 2
        self.draw_tracks = False
        self.track_color = (0, 255, 0)

        # Check if environment support imshow
        self.env_check = check_imshow(warn=True)

    def set_args(
        self,
        classes_names,
        reg_pts,
        count_reg_color=(255, 0, 255),
        line_thickness=2,
        track_thickness=2,
        view_img=False,
        view_in_counts=True,
        view_out_counts=True,
        draw_tracks=False,
        count_txt_thickness=2,
        count_txt_color=(0, 0, 0),
        count_color=(255, 255, 255),
        track_color=(0, 255, 0),
        region_thickness=5,
        line_dist_thresh=15,
    ):
        """
        Configures the Counter's image, bounding box line thickness, and counting region points.

        Args:
            line_thickness (int): Line thickness for bounding boxes.
            view_img (bool): Flag to control whether to display the video stream.
            view_in_counts (bool): Flag to control whether to display the incounts on video stream.
            view_out_counts (bool): Flag to control whether to display the outcounts on video stream.
            reg_pts (list): Initial list of points defining the counting region.
            classes_names (dict): Classes names
            track_thickness (int): Track thickness
            draw_tracks (Bool): draw tracks
            count_txt_thickness (int): Text thickness for object counting display
            count_txt_color (RGB color): count text color value
            count_color (RGB color): count text background color value
            count_reg_color (RGB color): Color of object counting region
            track_color (RGB color): color for tracks
            region_thickness (int): Object counting Region thickness
            line_dist_thresh (int): Euclidean Distance threshold for line counter
        """
        self.tf = line_thickness
        self.view_img = view_img
        self.view_in_counts = view_in_counts
        self.view_out_counts = view_out_counts
        self.track_thickness = track_thickness
        self.draw_tracks = draw_tracks

        # Region and line selection
        if len(reg_pts) == 2:
            print("Line Counter Initiated.")
            self.reg_pts = reg_pts
            self.counting_region = LineString(self.reg_pts)
        elif len(reg_pts) == 4:
            print("Region Counter Initiated.")
            self.reg_pts = reg_pts
            self.counting_region = Polygon(self.reg_pts)
        else:
            print("Invalid Region points provided, region_points can be 2 or 4")
            print("Using Line Counter Now")
            self.counting_region = LineString(self.reg_pts)

        self.names = classes_names
        self.track_color = track_color
        self.count_txt_thickness = count_txt_thickness
        self.count_txt_color = count_txt_color
        self.count_color = count_color
        self.region_color = count_reg_color
        self.region_thickness = region_thickness
        self.line_dist_thresh = line_dist_thresh

    def mouse_event_for_region(self, event, x, y, flags, params):
        """
        This function is designed to move region with mouse events in a real-time video stream.

        Args:
            event (int): The type of mouse event (e.g., cv2.EVENT_MOUSEMOVE, cv2.EVENT_LBUTTONDOWN, etc.).
            x (int): The x-coordinate of the mouse pointer.
            y (int): The y-coordinate of the mouse pointer.
            flags (int): Any flags associated with the event (e.g., cv2.EVENT_FLAG_CTRLKEY,
                cv2.EVENT_FLAG_SHIFTKEY, etc.).
            params (dict): Additional parameters you may want to pass to the function.
        """
        if event == cv2.EVENT_LBUTTONDOWN:
            for i, point in enumerate(self.reg_pts):
                if (
                    isinstance(point, (tuple, list))
                    and len(point) >= 2
                    and (abs(x - point[0]) < 10 and abs(y - point[1]) < 10)
                ):
                    self.selected_point = i
                    self.is_drawing = True
                    break

        elif event == cv2.EVENT_MOUSEMOVE:
            if self.is_drawing and self.selected_point is not None:
                self.reg_pts[self.selected_point] = (x, y)
                self.counting_region = Polygon(self.reg_pts)

        elif event == cv2.EVENT_LBUTTONUP:
            self.is_drawing = False
            self.selected_point = None

    def extract_and_process_tracks(self, tracks):
        """Extracts and processes tracks for object counting in a video stream."""
        boxes = tracks[0].boxes.xyxy.cpu()
        clss = tracks[0].boxes.cls.cpu().tolist()
        track_ids = tracks[0].boxes.id.int().cpu().tolist()

        # Annotator Init and region drawing
        self.annotator = Annotator(self.im0, self.tf, self.names)
        self.annotator.draw_region(reg_pts=self.reg_pts, color=self.region_color, thickness=self.region_thickness)

        # Extract tracks
        for box, track_id, cls in zip(boxes, track_ids, clss):
            # Draw bounding box
            self.annotator.box_label(box, label=f"{track_id}:{self.names[cls]}", color=colors(int(cls), True))

            # Draw Tracks
            track_line = self.track_history[track_id]
            track_line.append((float((box[0] + box[2]) / 2), float((box[1] + box[3]) / 2)))
            if len(track_line) > 30:
                track_line.pop(0)

            # Draw track trails
            if self.draw_tracks:
                self.annotator.draw_centroid_and_tracks(
                    track_line, color=self.track_color, track_thickness=self.track_thickness
                )

            prev_position = self.track_history[track_id][-2] if len(self.track_history[track_id]) > 1 else None

            # Count objects
            if len(self.reg_pts) == 4:
                if (
                    prev_position is not None
                    and self.counting_region.contains(Point(track_line[-1]))
                    and track_id not in self.counting_list
                ):
                    self.counting_list.append(track_id)
                    if (box[1] - prev_position[1]) * (self.counting_region.centroid.y - prev_position[1]) > 0:
                        self.in_counts += 1
                    else:
                        self.out_counts += 1

            elif len(self.reg_pts) == 2:
                if prev_position is not None:
                    distance = Point(track_line[-1]).distance(self.counting_region)
                    if distance < self.line_dist_thresh and track_id not in self.counting_list:
                        self.counting_list.append(track_id)
                        if (box[1] - prev_position[1]) * (self.counting_region.centroid.y - prev_position[1]) > 0:
                            self.in_counts += 1
                        else:
                            self.out_counts += 1

        incount_label = f"In Count : {self.in_counts}"
        outcount_label = f"OutCount : {self.out_counts}"

        # Display counts based on user choice
        counts_label = None
        if not self.view_in_counts and not self.view_out_counts:
            counts_label = None
        elif not self.view_in_counts:
            counts_label = outcount_label
        elif not self.view_out_counts:
            counts_label = incount_label
        else:
            counts_label = f"{incount_label} {outcount_label}"

        if counts_label is not None:
            self.annotator.count_labels(
                counts=counts_label,
                count_txt_size=self.count_txt_thickness,
                txt_color=self.count_txt_color,
                color=self.count_color,
            )

    def display_frames(self):
        """Display frame."""
        if self.env_check:
            cv2.namedWindow("Ultralytics YOLOv8 Object Counter")
            if len(self.reg_pts) == 4:  # only add mouse event If user drawn region
                cv2.setMouseCallback(
                    "Ultralytics YOLOv8 Object Counter", self.mouse_event_for_region, {"region_points": self.reg_pts}
                )
            
            cv2.imshow("Ultralytics YOLOv8 Object Counter", self.im0)
            # Break Window
            if cv2.waitKey(1) & 0xFF == ord("q"):
                return

    def start_counting(self, im0, tracks):
        """
        Main function to start the object counting process.

        Args:
            im0 (ndarray): Current frame from the video stream.
            tracks (list): List of tracks obtained from the object tracking process.
        """
        self.im0 = im0  # store image

        if tracks[0].boxes.id is None:
            if self.view_img:
                self.display_frames()
            # Annotator Init and region drawing
            self.annotator = Annotator(self.im0, self.tf, self.names)
            self.annotator.draw_region(reg_pts=self.reg_pts, color=self.region_color, thickness=self.region_thickness)

            incount_label = f"In Count : {self.in_counts}"
            outcount_label = f"OutCount : {self.out_counts}"

            # Display counts based on user choice
            counts_label = None
            if not self.view_in_counts and not self.view_out_counts:
                counts_label = None
            elif not self.view_in_counts:
                counts_label = outcount_label
            elif not self.view_out_counts:
                counts_label = incount_label
            else:
                counts_label = f"{incount_label} {outcount_label}"

            if counts_label is not None:
                self.annotator.count_labels(
                    counts=counts_label,
                    count_txt_size=self.count_txt_thickness,
                    txt_color=self.count_txt_color,
                    color=self.count_color,
                )
            return im0
        self.extract_and_process_tracks(tracks)

        if self.view_img:
            self.display_frames()
        return self.im0


# if __name__ == "__main__":
#     ObjectCounter()

# %%
set_fps = 5

# %%
model = YOLO("assets/yolov8l.pt")
vs = cv2.VideoCapture(SOURCE_VIDEO)

video_writer = cv2.VideoWriter(DESTINATION_VIDEO,
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       set_fps,
                       (1280, 720))

# %%
w, h, fps = (int(vs.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

fps //= set_fps
line_points = [(343, 387), (593, 317)]
square_points = [(343, 387), (593, 317), (610,350), (360, 420)]  # line or region points
classes_to_count = [2,3,5,7] # car, motorcycle, bus, truck classes for count

# Init Object Counter
counter = ObjectCounter()
counter.set_args(view_img=False,
                 reg_pts=line_points,
                 classes_names=model.names,
                 draw_tracks=False,
                 view_in_counts=True,
                 view_out_counts=True)
count = 0
while vs.isOpened():
    before = datetime.now()
    success, frame = vs.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    frame = cv2.resize(frame, (1280, 720)) # 1280 x 720 resolution
    tracks = model.track(frame, conf=0.1, iou=0.1, persist=True, show=False,
                         classes=classes_to_count, verbose=False)

    frame = counter.start_counting(frame, tracks)
    count += fps
    video_writer.write(frame)
    vs.set(cv2.CAP_PROP_POS_FRAMES, count)
    print(f"resolusi : {frame.shape[1]} x {frame.shape[0]}")
    print("total frame : ", vs.get(7))
    after = datetime.now()
    print('waktu analytics 1 frame : ', (after-before))
    print("frame ke " + str(count))
    print('====================================================================================================')
    

vs.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Line Counter Initiated.
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.906873
# frame ke 4
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.355141
# frame ke 8
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.366751
# frame ke 12
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.358445
# frame ke 16
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.362489
# frame ke 20
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.368033
# frame ke 24
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.377883
# frame ke 28
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.393615
# frame ke 32
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.411785
# frame ke 36
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.394789
# frame ke 40
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.399881
# frame ke 44
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.466783
# frame ke 48
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.445670
# frame ke 52
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.573584
# frame ke 56
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.513719
# frame ke 60
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.488882
# frame ke 64
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.490855
# frame ke 68
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.475693
# frame ke 72
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.471048
# frame ke 76
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.495090
# frame ke 80
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.497135
# frame ke 84
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.552946
# frame ke 88
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.506046
# frame ke 92
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.569103
# frame ke 96
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.536896
# frame ke 100
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.587504
# frame ke 104
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.568920
# frame ke 108
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.553329
# frame ke 112
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.648388
# frame ke 116
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.596424
# frame ke 120
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.579632
# frame ke 124
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.664125
# frame ke 128
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.637600
# frame ke 132
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.600419
# frame ke 136
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.602542
# frame ke 140
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.704590
# frame ke 144
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.675284
# frame ke 148
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.726721
# frame ke 152
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.767308
# frame ke 156
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.772287
# frame ke 160
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.755028
# frame ke 164
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.382510
# frame ke 168
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.412863
# frame ke 172
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.407410
# frame ke 176
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.430270
# frame ke 180
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.406121
# frame ke 184
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.445317
# frame ke 188
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.531845
# frame ke 192
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.479769
# frame ke 196
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.487097
# frame ke 200
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.493632
# frame ke 204
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.507422
# frame ke 208
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.546307
# frame ke 212
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.527472
# frame ke 216
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.540656
# frame ke 220
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.506441
# frame ke 224
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.567523
# frame ke 228
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.561607
# frame ke 232
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.635523
# frame ke 236
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.690846
# frame ke 240
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.595615
# frame ke 244
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.593832
# frame ke 248
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.593347
# frame ke 252
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.620651
# frame ke 256
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.668971
# frame ke 260
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.652567
# frame ke 264
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.725505
# frame ke 268
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.657563
# frame ke 272
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.639331
# frame ke 276
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.657138
# frame ke 280
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.662898
# frame ke 284
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.746638
# frame ke 288
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.701344
# frame ke 292
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.727146
# frame ke 296
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.773918
# frame ke 300
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.770716
# frame ke 304
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.733075
# frame ke 308
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.757288
# frame ke 312
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.385720
# frame ke 316
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.410186
# frame ke 320
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.384743
# frame ke 324
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.616506
# frame ke 328
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.673386
# frame ke 332
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.955495
# frame ke 336
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.895480
# frame ke 340
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.771864
# frame ke 344
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.685624
# frame ke 348
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.718907
# frame ke 352
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.701963
# frame ke 356
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.717279
# frame ke 360
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.751373
# frame ke 364
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.691934
# frame ke 368
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.668925
# frame ke 372
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.696971
# frame ke 376
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.750163
# frame ke 380
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.893459
# frame ke 384
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.028127
# frame ke 388
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.034803
# frame ke 392
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.961040
# frame ke 396
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.827458
# frame ke 400
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.845720
# frame ke 404
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.851176
# frame ke 408
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.761930
# frame ke 412
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.946696
# frame ke 416
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.932755
# frame ke 420
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.866773
# frame ke 424
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.915688
# frame ke 428
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.940995
# frame ke 432
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.836114
# frame ke 436
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.801563
# frame ke 440
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.859480
# frame ke 444
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.889170
# frame ke 448
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.980788
# frame ke 452
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.955999
# frame ke 456
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.989347
# frame ke 460
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.925111
# frame ke 464
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.474880
# frame ke 468
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.599315
# frame ke 472
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.506384
# frame ke 476
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.644642
# frame ke 480
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.592715
# frame ke 484
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.563877
# frame ke 488
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.694224
# frame ke 492
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.657364
# frame ke 496
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.668023
# frame ke 500
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.643806
# frame ke 504
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.728100
# frame ke 508
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.628941
# frame ke 512
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.648596
# frame ke 516
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.642447
# frame ke 520
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.684391
# frame ke 524
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.797524
# frame ke 528
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.724389
# frame ke 532
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.770413
# frame ke 536
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.795788
# frame ke 540
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.824330
# frame ke 544
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.794127
# frame ke 548
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.811493
# frame ke 552
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.799092
# frame ke 556
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.779304
# frame ke 560
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.809300
# frame ke 564
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.807088
# frame ke 568
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.832477
# frame ke 572
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.898619
# frame ke 576
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.852153
# frame ke 580
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.847377
# frame ke 584
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.919549
# frame ke 588
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.872438
# frame ke 592
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.853857
# frame ke 596
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.924839
# frame ke 600
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.915531
# frame ke 604
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.902005
# frame ke 608
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.918643
# frame ke 612
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.477250
# frame ke 616
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.552258
# frame ke 620
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.588661
# frame ke 624
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.548881
# frame ke 628
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.665719
# frame ke 632
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.566213
# frame ke 636
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.642463
# frame ke 640
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.572685
# frame ke 644
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.656318
# frame ke 648
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.664185
# frame ke 652
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.687628
# frame ke 656
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.702707
# frame ke 660
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.711091
# frame ke 664
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.712643
# frame ke 668
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.748714
# frame ke 672
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.709136
# frame ke 676
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.711506
# frame ke 680
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.707394
# frame ke 684
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.729822
# frame ke 688
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.781116
# frame ke 692
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.008206
# frame ke 696
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.883704
# frame ke 700
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.819882
# frame ke 704
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.834368
# frame ke 708
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.865161
# frame ke 712
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.848237
# frame ke 716
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.885546
# frame ke 720
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.805457
# frame ke 724
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.855275
# frame ke 728
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.812240
# frame ke 732
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.819719
# frame ke 736
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.858688
# frame ke 740
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.914632
# frame ke 744
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.031963
# frame ke 748
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.974144
# frame ke 752
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.996909
# frame ke 756
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.960868
# frame ke 760
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.691798
# frame ke 764
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.696037
# frame ke 768
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.121712
# frame ke 772
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.115584
# frame ke 776
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.049528
# frame ke 780
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.107203
# frame ke 784
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.187661
# frame ke 788
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.088962
# frame ke 792
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.426082
# frame ke 796
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.056961
# frame ke 800
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.397807
# frame ke 804
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.253444
# frame ke 808
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.249811
# frame ke 812
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.383525
# frame ke 816
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.403539
# frame ke 820
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.426864
# frame ke 824
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.400680
# frame ke 828
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.406614
# frame ke 832
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.348723
# frame ke 836
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.410333
# frame ke 840
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.485689
# frame ke 844
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.667731
# frame ke 848
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.752675
# frame ke 852
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.738502
# frame ke 856
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.730562
# frame ke 860
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.678343
# frame ke 864
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.672013
# frame ke 868
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.685142
# frame ke 872
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.578141
# frame ke 876
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.686133
# frame ke 880
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.653468
# frame ke 884
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.631810
# frame ke 888
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.677144
# frame ke 892
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.669517
# frame ke 896
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.824525
# frame ke 900
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.778091
# frame ke 904
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.772485
# frame ke 908
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.944596
# frame ke 912
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.899872
# frame ke 916
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.970922
# frame ke 920
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.941416
# frame ke 924
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.078170
# frame ke 928
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.956359
# frame ke 932
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.999724
# frame ke 936
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.967490
# frame ke 940
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.057506
# frame ke 944
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.135050
# frame ke 948
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.113405
# frame ke 952
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.066278
# frame ke 956
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.181146
# frame ke 960
# ====================================================================================================
# ...
# frame ke 6268
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.593638
# frame ke 6272
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.450611
# frame ke 6276
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.428228
# frame ke 6280
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.718723
# frame ke 6284
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.569533
# frame ke 6288
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.801341
# frame ke 6292
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.618397
# frame ke 6296
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.833476
# frame ke 6300
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.692809
# frame ke 6304
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.854377
# frame ke 6308
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.701278
# frame ke 6312
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.000735
# frame ke 6316
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.088582
# frame ke 6320
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.039299
# frame ke 6324
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:00.926479
# frame ke 6328
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.022372
# frame ke 6332
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.309105
# frame ke 6336
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.330180
# frame ke 6340
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.252878
# frame ke 6344
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.109527
# frame ke 6348
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.294037
# frame ke 6352
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.390225
# frame ke 6356
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.368273
# frame ke 6360
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.235432
# frame ke 6364
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.228430
# frame ke 6368
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.447072
# frame ke 6372
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.312785
# frame ke 6376
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.403516
# frame ke 6380
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.477767
# frame ke 6384
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.418071
# frame ke 6388
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.353143
# frame ke 6392
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.494803
# frame ke 6396
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.605375
# frame ke 6400
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.519266
# frame ke 6404
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.481299
# frame ke 6408
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.685312
# frame ke 6412
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.730897
# frame ke 6416
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.703450
# frame ke 6420
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.763528
# frame ke 6424
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.669454
# frame ke 6428
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.838981
# frame ke 6432
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.787914
# frame ke 6436
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.781497
# frame ke 6440
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:02.014175
# frame ke 6444
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.853352
# frame ke 6448
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.958925
# frame ke 6452
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.913283
# frame ke 6456
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:02.473083
# frame ke 6460
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.985355
# frame ke 6464
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.165760
# frame ke 6468
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.086033
# frame ke 6472
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.212243
# frame ke 6476
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.395156
# frame ke 6480
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.221466
# frame ke 6484
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.314638
# frame ke 6488
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.237921
# frame ke 6492
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.257740
# frame ke 6496
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.290201
# frame ke 6500
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.445317
# frame ke 6504
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.402655
# frame ke 6508
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.456688
# frame ke 6512
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.275177
# frame ke 6516
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.407660
# frame ke 6520
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.459667
# frame ke 6524
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.401220
# frame ke 6528
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.400564
# frame ke 6532
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.466553
# frame ke 6536
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.635611
# frame ke 6540
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.581448
# frame ke 6544
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.679685
# frame ke 6548
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.519480
# frame ke 6552
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.712523
# frame ke 6556
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.632876
# frame ke 6560
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.817319
# frame ke 6564
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.648882
# frame ke 6568
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.832311
# frame ke 6572
# ====================================================================================================
# resolusi : 1280 x 720
# total frame :  6575.0
# waktu analytics 1 frame :  0:00:01.625665
# frame ke 6576
# ====================================================================================================
# Video frame is empty or video processing has been successfully completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
